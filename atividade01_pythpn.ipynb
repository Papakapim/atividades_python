# %% [markdown]
# <a href="https://colab.research.google.com/github/Papakapim/atividades_python/blob/main/atividade01_pythpn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Aprendendo versionamento de projetos!")
# Atividade 01 — Introdução ao Python
print("Olá, mundo!")
print("Minha primeira atividade no Google Colab")
print("Aprendendo Python e GitHub")
print("Curso Técnico em Informática")
disciplina = input("Digite o nome da disciplina: ")
conteudo = input("Digite o conteúdo estudado: ")
atividade = input("Digite o número da atividade: ")
print("\n--- Informações da atividade ---")
print("Disciplina:", disciplina)
print("Conteúdo:", conteudo)
print("Atividade:", atividade)
# Out:
# Aprendendo versionamento de projetos!
# Olá, mundo!
# Minha primeira atividade no Google Colab
# Aprendendo Python e GitHub
# Curso Técnico em Informática
# Digite o nome da disciplina: Algoritmos e lógica de programação
# Digite o conteúdo estudado: Introdução ao python e github
# Digite o número da atividade: 01
#
# --- Informações da atividade ---
# Disciplina: Algoritmos e lógica de programação
# Conteúdo: Introdução ao python e github
# Atividade: 01
