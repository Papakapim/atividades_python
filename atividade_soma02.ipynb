# %% [markdown]
# <a href="https://colab.research.google.com/github/Papakapim/atividades_python/blob/main/atividade_soma02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Adicionando um novo notebook no github
numero1 = float(input("Digite um número: "))
numero2 = float(input("Digite um outro número: "))
soma = numero1 + numero2
print(f"A soma desses dois números é {soma}")
# Out:
# Digite um número: 99
# Digite um outro número: 1
# A soma desses dois números é 100.0
